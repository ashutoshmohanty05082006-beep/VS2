# %% [markdown]
# # Exploratory Data Analysis (EDA)
# Use this notebook to explore uploaded datasets.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Example: load a CSV from the workspace if present
# df = pd.read_csv('../data/your_file.csv')
# df.head()

# %%
# Missing Value Heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %%
# Distribution Plots
df.hist(figsize=(10, 10))
plt.tight_layout()
plt.show()

# %%
# Target Correlation (replace 'target_column' with your actual target)
correlation = df.corr()['target_column'].sort_values(ascending=False)
print(correlation)
